# %%
import pygyre as pg
import matplotlib.pyplot as plt
import numpy as np

# %%
s = pg.read_output('summary.h5')

# %%
s
# Out:
# <Table length=9>
#         E_norm                   freq          ...  n_pg          omega
#        float64                complex128       ... int32        complex128
# ---------------------- ----------------------- ... ----- -----------------------
#     19.806390126976062 (16.250860916685664+0j) ...    -3 (0.6218866055204929+0j)
#     14.623751299124176 (21.731525372568495+0j) ...    -2 (0.8316202209849048+0j)
#      3.339758462842171  (32.63386002753691+0j) ...    -1  (1.248829864559254+0j)
#     0.1431273402660151 (41.134830049388384+0j) ...     0 (1.5741442843690128+0j)
#   0.015303492667346836   (85.6446633569697+0j) ...     1  (3.277442915121187+0j)
#   0.003205238417434325 (128.42476059118047+0j) ...     2  (4.914548148450935+0j)
#   0.000981987642085043 (170.00134561301397+0j) ...     3  (6.505597475678545+0j)
# 0.00036791574452147303 (210.44785885562553+0j) ...     4   (8.05340130924414+0j)
# 0.00015674954220690088 (249.92587215747307+0j) ...     5   (9.56414266693868+0j)

# %%
d = pg.read_output('detail.l2.n+0.h5')

# %%
plt.figure()

plt.plot(d['x'], d['xi_r'].real, label='xi_r')
plt.plot(d['x'], d['xi_h'].real, label='xi_h')

plt.xlabel('x')

plt.legend()

# %%
l = d.meta['l']
omega = d.meta['omega']

x = d['x']
V = d['V_2']*d['x']**2
As = d['As']
c_1 = d['c_1']
Gamma_1 = d['Gamma_1']

d['N2'] = d['As']/d['c_1']
d['Sl2'] = l*(l+1)*Gamma_1/(V*c_1)

# Plot the propagation diagram

plt.figure()

plt.plot(d['x'], d['N2'], label='N^2')
plt.plot(d['x'], d['Sl2'], label='S_l^2')

plt.axhline(omega.real**2, dashes=(4,2))

plt.xlabel('x')
plt.ylabel('omega^2')

plt.ylim(5e-2, 5e2)
plt.yscale('log')
# Out:
# /tmp/ipykernel_3400252/2715802805.py:11: RuntimeWarning: divide by zero encountered in divide
#   d['Sl2'] = l*(l+1)*Gamma_1/(V*c_1)
