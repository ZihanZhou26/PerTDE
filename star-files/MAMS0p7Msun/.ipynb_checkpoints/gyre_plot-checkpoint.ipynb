# %%
import pygyre as pg
import matplotlib.pyplot as plt
import numpy as np

# %%
s = pg.read_output('summary.h5')

# %%
s
# Out:
# <Table length=20>
#         E_norm                M_star        ...  n_pg          omega
#        float64               float64        ... int32        complex128
# --------------------- --------------------- ... ----- -----------------------
#     7.718444482430179 1.391886909488635e+33 ...   -14 (0.5234354988770084+0j)
#     6.860412629291425 1.391886909488635e+33 ...   -13 (0.5601516203279491+0j)
#     5.868667123284612 1.391886909488635e+33 ...   -12 (0.6021580722922453+0j)
#     5.034183711885262 1.391886909488635e+33 ...   -11 (0.6508827269789529+0j)
#     4.388012145527391 1.391886909488635e+33 ...   -10 (0.7074225620125895+0j)
#     3.695589717187485 1.391886909488635e+33 ...    -9 (0.7742027772872123+0j)
#    2.8938451787654076 1.391886909488635e+33 ...    -8 (0.8546665332750415+0j)
#    2.1432621517334356 1.391886909488635e+33 ...    -7 (0.9524900704111988+0j)
#    1.5778512698578302 1.391886909488635e+33 ...    -6 (1.0725848826409607+0j)
#    1.0585304149646724 1.391886909488635e+33 ...    -5  (1.220859986786113+0j)
#    0.5649589566630238 1.391886909488635e+33 ...    -4 (1.4114857286766678+0j)
#   0.24067767560359124 1.391886909488635e+33 ...    -3 (1.6470951896094308+0j)
#   0.11576694581769366 1.391886909488635e+33 ...    -2 (1.9322797540016683+0j)
#   0.05833150098757628 1.391886909488635e+33 ...    -1 (2.2449438560385087+0j)
#   0.22464139269278396 1.391886909488635e+33 ...     0  (2.693200529828142+0j)
#  0.004563942583899206 1.391886909488635e+33 ...     1 (3.4930165148805887+0j)
# 0.0008634206429988184 1.391886909488635e+33 ...     2  (5.038340460254392+0j)
# 0.0002499702899969633 1.391886909488635e+33 ...     3  (6.595494238235083+0j)
# 8.785392769868774e-05 1.391886909488635e+33 ...     4  (8.090448452285536+0j)
#  3.36499195265762e-05 1.391886909488635e+33 ...     5  (9.583955822169095+0j)

# %%
d = pg.read_output('detail.l2.n-6.h5')

# %%
c0 = 299792458
GNewton = 6.67408*10**(-11)

Rstar=s['R_star'][1] / 100
Mstar = s['M_star'][1] / 1000
M_r = d['M_r'] / 1000

rho_Dles = (d['rho'] * 10**3) * Rstar**2 * GNewton/ c0**2
M_Dles = Mstar * GNewton/ c0**2 / Rstar
Mr_Dles = M_r * GNewton/ c0**2 / Rstar

# %%
Rstar / (6.957 * 10 ** 8)
# Out:
# 0.7036765127539467

# %%
np.trapz(4.0*(np.pi)*(d['x'])*(rho_Dles)*Mr_Dles,d['x']) / (M_Dles**2)
# Out:
# 1.2967692509184983

# %%
1/((rho_Dles[0]/(M_Dles/ (4/3 *np.pi)))**(1/3)*0.5)
# Out:
# 0.5229409997773395

# %%
plt.figure()

plt.plot(d['x'], d['xi_r'].real, label='xi_r')
plt.plot(d['x'], d['xi_h'].real, label='xi_h')

plt.xlabel('x')

plt.legend()

# %%
l = d.meta['l']
omega = d.meta['omega']

x = d['x']
V = d['V_2']*d['x']**2
As = d['As']
c_1 = d['c_1']
Gamma_1 = d['Gamma_1']

d['N2'] = d['As']/d['c_1']
d['Sl2'] = l*(l+1)*Gamma_1/(V*c_1)

# Plot the propagation diagram

plt.figure()

plt.plot(d['x'], d['N2'], label='N^2')
plt.plot(d['x'], d['Sl2'], label='S_l^2')

plt.axhline(omega.real**2, dashes=(4,2))

plt.xlabel('x')
plt.ylabel('omega^2')

plt.ylim(5e-2, 5e2)
plt.yscale('log')
# Out:
# /tmp/ipykernel_3463748/2715802805.py:11: RuntimeWarning: divide by zero encountered in divide
#   d['Sl2'] = l*(l+1)*Gamma_1/(V*c_1)

# %%
D_overlap = np.trapz(rho_Dles *( d['x']**3 * d['xi_r'] + 3 * d['x']**2 * (d['x'] * d['xi_h'])),d['x']) / M_Dles

# %%
N_overlap= np.trapz(rho_Dles *( d['x']**2 * d['xi_r']**2 + 6 * (d['x'] * d['xi_h'])**2 ),d['x']) / M_Dles

# %%
D_overlap **2 / N_overlap
# Out:
# (0.00012653617400116253+0j)
